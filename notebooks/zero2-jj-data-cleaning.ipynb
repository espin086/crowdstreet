# %%
import pandas as pd 
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# %%
list_of_vars = ['sponsor', 
                'sponsor_experience', 
                'offering', 
                'offering_city', 
                'offering_state',
                'property_type', 
                'investment_structure', 
                'investment_profile',
                'investor_accreditation',
                '1031_exchange',
                'opportunity_zone',
                'offering_status',
               ]


def lower_and_strip_vars(df, list_of_vars):
    df.columns = df.columns.str.strip().str.lower()\
        .str.replace(' ', '_')\
        .str.replace('?', '')\
        .str.replace('(', '')\
        .str.replace(')', '')\
        .str.replace('%', 'pct')\
        .str.replace('-', '_')\
        .str.replace('$', 'dollars')
    for var in list_of_vars:
        df[var] = df[var].str.lower()
        df[var] = df[var].str.strip()
    return df

def drop_vars(df, list_of_vars):
    df = df.drop(list_of_vars, axis=1)
    return df

# %%
date_vars = ['date_closed', 
             'targeted_first_distribution_date', 
             'date_funds_due',
             'first_distribution_period_end_date',
             'first_distribution_payment_date', 
             'last_distribution_period_end_date',
             'last_tax_document_date',
             'last_distribution_payment_date',
            ]
def change_to_date_datatypes(df, date_vars):
    for var in date_vars:
        df[var] = pd.to_datetime(df[var])
    return df

# %%
def explore_column_w_fuzzwuzzy(df, column):
    choices = list(df[column].unique())
    fuzzy_matches = {}
    for value in choices:
         fuzzy_matches[value] = process.extract(str(value), choices, scorer=fuzz.token_sort_ratio)
    return fuzzy_matches

# %%
def check_fuzzy_matches(df, var):
    fuzzy_matches = explore_column_w_fuzzwuzzy(df=df, column=var)
    top_counts = df[var].value_counts().head(20)
    bottom_counts = df[var].value_counts().tail(20)
    return fuzzy_matches, top_counts, bottom_counts

# %%
def clean_dirty_column(df, var, old_string, new_string):
    contains_str = df[var].str.contains(old_string)
    df[var] = np.where(contains_str, new_string, df[var])
    return df

# %%
def doing_dirty_column_cleaning(df):
    df = clean_dirty_column(df=df,var='offering_city', old_string='multiple', new_string='multiple')
    df = clean_dirty_column(df=df,var='offering_city', old_string='new york', new_string='new york')
    df = clean_dirty_column(df=df,var='offering_city', old_string='atlanta', new_string='atlanta')

    df = clean_dirty_column(df=df,var='offering_state', old_string='multiple', new_string='multiple')
    df = clean_dirty_column(df=df,var='offering_state', old_string='u.s.', new_string='multiple')
    df = clean_dirty_column(df=df,var='offering_state', old_string='ms & al', new_string='multiple')
    df = clean_dirty_column(df=df,var='offering_state', old_string='usa', new_string='multiple')
    df = clean_dirty_column(df=df,var='offering_state', old_string='oregon', new_string='or')
    df = clean_dirty_column(df=df,var='offering_state', old_string='north carolina', new_string='nc')
    df = clean_dirty_column(df=df,var='offering_state', old_string='iowa', new_string='ia')
    df = clean_dirty_column(df=df,var='offering_state', old_string='colorado', new_string='co')

    df = clean_dirty_column(df=df,var='property_type', old_string='mixed use', new_string='multi-use')
    df = clean_dirty_column(df=df,var='property_type', old_string='medical office', new_string='office')
    df = clean_dirty_column(df=df,var='property_type', old_string='flex r&d', new_string='multi-use')

    df = clean_dirty_column(df=df,var='property_type', old_string='residential', new_string='multifamily')
    df = clean_dirty_column(df=df,var='investment_structure', old_string='equity', new_string='equity')
    df = clean_dirty_column(df=df,var='investment_structure', old_string='debt', new_string='debt')
    
    return df

# %%
def clean_crowd_street(infile, outfile):
    df = pd.read_csv(infile)
    df = lower_and_strip_vars(df=df,list_of_vars=list_of_vars)
    df = drop_vars(df=df, list_of_vars=['disposition_date', 'realized_investor_irr_pct'])
    df = change_to_date_datatypes(df=df, date_vars=date_vars)
    df = doing_dirty_column_cleaning(df=df)
    
    #cleaning discrepency in reporting percentages
    df['realized_avg_annual_cash_yield_pct'] = np.where(df['realized_avg_annual_cash_yield_pct'] > 0,\
         df['realized_avg_annual_cash_yield_pct'] / 100,\
         df['realized_avg_annual_cash_yield_pct'])
    
    df.to_csv(outfile, index=False)

    return df

# %%
clean_crowd_street(infile="../data/raw/Offerings_2019-10-25.csv", 
                   outfile="../data/processed/clean_crowdstreet.csv"
                  )
# Out:
#                                   sponsor sponsor_experience  \
# 0                 crowdstreet investments            blended
# 1                    crowdstreet advisors            blended
# 2                    crowdstreet advisors            blended
# 3                        trion properties           seasoned
# 4                   capstone realty group            tenured
# 5                                 westpac            tenured
# 6    cascadia senior living & development           seasoned
# 7              one real estate investment           seasoned
# 8                                     ssi            tenured
# 9         middleburg real estate partners            tenured
# 10              flywheel capital partners           emerging
# 11                            block funds            tenured
# 12                             bridgeview           seasoned
# 13                            block funds            tenured
# 14                         liquid capital           emerging
# 15                      vertical ventures           seasoned
# 16                         mcfarlin group           seasoned
# 17                crowdstreet investments            blended
# 18                       trueline capital           emerging
# 19                           gwr equities           seasoned
# 20               rhodium capital advisors           seasoned
# 21                    denholtz properties            tenured
# 22                           insite group            tenured
# 23                   emerald equity group           seasoned
# 24                                    prp            tenured
# 25               rhodium capital advisors           seasoned
# 26                              driftwood            tenured
# 27                    phoenix development           seasoned
# 28                     presidio companies            tenured
# 29                     guefen development            tenured
# ..                                    ...                ...
# 294                    mascia development           seasoned
# 295                       virtua partners           emerging
# 296          brooklyn standard properties           emerging
# 297                        smartcap, inc.           seasoned
# 298                   denholtz properties            tenured
# 299                    encore enterprises            tenured
# 300                    emerge investments           emerging
# 301               intellistay hospitality           emerging
# 302              cadence asset management           seasoned
# 303                   denholtz properties            tenured
# 304                       virtua partners           emerging
# 305               keystone property group            tenured
# 306                           urban green           seasoned
# 307                 global senior housing           emerging
# 308                    encore enterprises            tenured
# 309                     hayman properties           seasoned
# 310                      olympus property            tenured
# 311             westmount realty equities            tenured
# 312                     kleban properties           seasoned
# 313                              bancroft            tenured
# 314             westmount realty equities            tenured
# 315                   capital real estate            tenured
# 316                     aldwin apartments           emerging
# 317              phoinix capital partners           emerging
# 318        the william warren group, inc.            tenured
# 319                            mainstreet           seasoned
# 320             windmill investments, llc           seasoned
# 321                     aldwin apartments           emerging
# 322                           urban green           seasoned
# 323         everwest real estate partners            tenured
#
#                                               offering        offering_city  \
# 0             crowdstreet blended portfolio - series v             multiple
# 1     private managed accounts by crowdstreet advisors             portland
# 2               crowdstreet opportunity zone portfolio             multiple
# 3                                   meadows apartments               newark
# 4                                1700 palm beach lakes      west palm beach
# 5                          elevation at okemos (ph ii)               okemos
# 6                    fieldstone memory care - puyallup             puyallup
# 7                           axiom apartments charlotte            charlotte
# 8                                      61 state street           charleston
# 9                                    mosby riverlights           wilmington
# 10                   colorado springs office portfolio     colorado springs
# 11                                 villas at waterside               lenexa
# 12                               bv multifamily fund i             multiple
# 13                              westowne center retail      west des moines
# 14                           avia riverside apartments              roswell
# 15                            vertical ventures fund i  greater sf bay area
# 16                                 the ivy of mckinney             mckinney
# 17         crowdstreet blended portfolio - summer 2019             multiple
# 18                            trueline capital fund ii    pacific northwest
# 19                                 trails at city park              houston
# 20                             summit ridge apartments            charlotte
# 21                            deerfield corporate park      deerfield beach
# 22   holiday inn & suites across from universal orl...              orlando
# 23                      the crest at princeton meadows           plainsboro
# 24                                  nobu restaurant dc           washington
# 25                              the willows apartments               kileen
# 26               ft. lauderdale opportunity zone hotel      fort lauderdale
# 27   226 w. jackson: dual branded hilton canopy and...              chicago
# 28                                        home2 suites      west sacramento
# 29                                     haven at denton               denton
# ..                                                 ...                  ...
# 294                                    val verde place             la vista
# 295                                   plymouth meeting     plymouth meeting
# 296                                         west 107th             new york
# 297                        south seattle business park              seattle
# 298                                   490 first avenue       st. petersburg
# 299                      encore gp acquisition fund ii             multiple
# 300                                 ivy at clear creek              houston
# 301                              intellistay boonville            boonville
# 302                         cadence retail income fund             multiple
# 303                               100 east pine street              orlando
# 304                        britannia business center i           pleasanton
# 305                               1200 corporate place           boca raton
# 306                  welbrook santa monica memory care         santa monica
# 307                          new haven assisted living               spring
# 308                            harrisonburg doubletree         harrisonburg
# 309                                      abb corporate          westerville
# 310                                    olympus fund iv             multiple
# 311                             westmount at colonnade        grand prairie
# 312                               2321 university blvd           tuscaloosa
# 313                                  sixth avenue west               golden
# 314                           westmount at summer cove        grand prairie
# 315              ponderosa ranch fka sienna apartments                tempe
# 316                                          oak chase           fort worth
# 317                          1380 garnet retail center            san diego
# 318                   storquest: tempe / warner (1063)                tempe
# 319                             mainstreet bloomington          bloomington
# 320                             timber oaks apartments           midlothian
# 321                             villas at leblanc park           fort worth
# 322                                      1924 franklin              oakland
# 323                                30 knightsbridge rd           piscataway
#
#     offering_state   property_type investment_structure investment_profile  \
# 0               or       multi-use               equity          value add
# 1               or       multi-use               equity          value add
# 2         multiple       multi-use               equity      opportunistic
# 3               ca     multifamily               equity          value add
# 4               fl          office               equity          value add
# 5               mi     multifamily               equity        development
# 6               wa  senior housing               equity        development
# 7               nc     multifamily               equity          core plus
# 8               sc     hospitality               equity          value add
# 9               nc     multifamily               equity        development
# 10              co          office               equity          core plus
# 11              ks     multifamily               equity      opportunistic
# 12        multiple       multi-use               equity      opportunistic
# 13              ia     multifamily               equity          core plus
# 14              ga     multifamily               equity          value add
# 15              ca       multi-use               equity      opportunistic
# 16              tx  senior housing               equity          value add
# 17        multiple       multi-use               equity          value add
# 18        multiple     multifamily                 debt          core plus
# 19              tx     multifamily               equity          value add
# 20              nc     multifamily               equity          value add
# 21              fl          office               equity          core plus
# 22              fl     hospitality               equity          value add
# 23              nj     multifamily               equity          core plus
# 24              dc          retail               equity          value add
# 25              tx     multifamily               equity          value add
# 26              fl     hospitality               equity        development
# 27              il     hospitality               equity      opportunistic
# 28              ca     hospitality               equity        development
# 29              tx     multifamily               equity      opportunistic
# ..             ...             ...                  ...                ...
# 294             ne          retail               equity          value add
# 295             pa     hospitality               equity          value add
# 296             ny     multifamily               equity          value add
# 297             wa       multi-use               equity          value add
# 298             fl          office               equity          value add
# 299       multiple       multi-use               equity      opportunistic
# 300             tx     multifamily               equity          value add
# 301             mo     hospitality               equity          value add
# 302       multiple       multi-use               equity          value add
# 303             fl          office               equity          value add
# 304             ca          office               equity      opportunistic
# 305             fl          office               equity          core plus
# 306             ca  senior housing               equity      opportunistic
# 307             tx  senior housing               equity      opportunistic
# 308             va     hospitality               equity          value add
# 309             oh          office               equity          value add
# 310       multiple       multi-use               equity               core
# 311             tx     multifamily               equity          value add
# 312             al       multi-use               equity          value add
# 313             co          office               equity          value add
# 314             tx     multifamily               equity          value add
# 315             az     multifamily               equity          value add
# 316             tx     multifamily               equity          value add
# 317             ca          retail               equity      opportunistic
# 318             az         storage               equity          core plus
# 319             in  senior housing                 debt          core plus
# 320             tx     multifamily               equity          value add
# 321             tx     multifamily               equity          value add
# 322             ca          office               equity          value add
# 323             nj          office                 debt          core plus
#
#      targeted_investor_irr_pct  targeted_investor_equity_multiple  ...  \
# 0                        18.00                               2.00  ...
# 1                          NaN                                NaN  ...
# 2                        10.00                               2.00  ...
# 3                        15.90                               1.50  ...
# 4                        19.10                               2.00  ...
# 5                        18.00                               1.60  ...
# 6                        22.50                               1.80  ...
# 7                        14.70                               1.90  ...
# 8                        17.40                               1.90  ...
# 9                        20.40                               1.70  ...
# 10                       18.60                               2.10  ...
# 11                       13.50                               3.60  ...
# 12                       22.00                               2.88  ...
# 13                       19.40                               2.20  ...
# 14                       18.90                               1.90  ...
# 15                       19.00                               2.00  ...
# 16                       19.10                               2.00  ...
# 17                       18.00                               2.50  ...
# 18                       11.00                               1.20  ...
# 19                       15.20                               2.50  ...
# 20                       19.80                               1.90  ...
# 21                       15.00                               1.90  ...
# 22                       18.50                               2.10  ...
# 23                       16.00                               2.30  ...
# 24                       14.30                               1.80  ...
# 25                       18.00                               1.80  ...
# 26                       12.70                               2.50  ...
# 27                       24.10                               4.20  ...
# 28                       18.60                               3.50  ...
# 29                       20.60                               1.80  ...
# ..                         ...                                ...  ...
# 294                      15.80                               1.95  ...
# 295                      21.70                               2.40  ...
# 296                      14.00                               1.60  ...
# 297                      20.40                               2.30  ...
# 298                      19.70                               2.30  ...
# 299                      24.00                               2.10  ...
# 300                      19.60                               2.24  ...
# 301                      24.30                               2.40  ...
# 302                      15.00                               2.01  ...
# 303                      17.60                               2.08  ...
# 304                      30.00                               2.20  ...
# 305                      14.40                               1.82  ...
# 306                      22.10                               2.60  ...
# 307                      24.30                               2.10  ...
# 308                      19.50                               2.20  ...
# 309                      17.50                               1.57  ...
# 310                      11.41                               7.80  ...
# 311                      18.30                               2.09  ...
# 312                      19.30                               2.10  ...
# 313                      17.00                               1.90  ...
# 314                      18.00                               2.00  ...
# 315                      17.00                               2.03  ...
# 316                      16.50                               1.81  ...
# 317                      23.70                               1.53  ...
# 318                      12.10                               2.40  ...
# 319                      14.00                               1.30  ...
# 320                      17.80                               2.14  ...
# 321                      19.60                               1.73  ...
# 322                      18.10                               1.60  ...
# 323                      10.50                               1.64  ...
#
#      date_funds_due date_closed  offering_status  \
# 0               NaT         NaT          funding
# 1               NaT         NaT          funding
# 2        2019-11-07  2019-11-04          funding
# 3        2019-11-05  2019-11-01          funding
# 4        2019-10-30         NaT          funding
# 5        2019-11-29  2019-11-26          funding
# 6        2019-11-29  2019-11-26          funding
# 7        2019-11-08  2019-11-05          funding
# 8        2019-11-15  2019-11-12          funding
# 9        2019-11-08  2019-11-05          funding
# 10       2019-10-25  2019-10-22           closed
# 11       2019-11-01  2019-10-22           closed
# 12       2019-10-25  2019-10-21           closed
# 13       2019-10-28  2019-10-18           closed
# 14       2019-10-15  2019-10-11           closed
# 15              NaT         NaT          funding
# 16       2019-10-25  2019-10-07           closed
# 17       2019-10-10  2019-10-03           closed
# 18              NaT  2019-10-01           closed
# 19       2019-11-08  2019-11-05          funding
# 20       2019-10-07  2019-09-27           closed
# 21       2019-10-10  2019-09-25           closed
# 22       2019-10-04  2019-09-23           closed
# 23       2019-09-19  2019-09-16           closed
# 24       2019-09-20  2019-09-06           closed
# 25       2019-09-06  2019-09-05           closed
# 26       2019-10-31  2019-10-29          funding
# 27       2019-09-19  2019-09-05           closed
# 28       2019-09-18  2019-08-27           closed
# 29       2019-08-28  2019-08-27           closed
# ..              ...         ...              ...
# 294             NaT  2016-05-12           closed
# 295             NaT  2016-05-12           closed
# 296             NaT  2016-04-30           closed
# 297             NaT  2016-04-19         realized
# 298             NaT  2016-04-12         realized
# 299             NaT  2016-02-23           closed
# 300             NaT  2016-02-12         realized
# 301             NaT  2016-02-12           closed
# 302             NaT  2016-02-12           closed
# 303             NaT  2016-02-11           closed
# 304             NaT  2016-01-28           closed
# 305             NaT  2016-01-13           closed
# 306             NaT  2016-01-05           closed
# 307             NaT  2016-01-04           closed
# 308             NaT  2016-01-02           closed
# 309             NaT  2016-01-01           closed
# 310             NaT  2015-11-20           closed
# 311             NaT  2015-11-16         realized
# 312             NaT  2015-11-06           closed
# 313             NaT  2015-10-02           closed
# 314             NaT  2015-09-27           closed
# 315             NaT  2015-08-31           closed
# 316             NaT  2015-08-23           closed
# 317             NaT  2015-07-24           closed
# 318             NaT  2015-06-30           closed
# 319             NaT  2015-06-07         realized
# 320             NaT  2015-06-04         realized
# 321             NaT  2015-04-16         realized
# 322             NaT  2015-04-03         realized
# 323             NaT  2015-01-27           closed
#
#     first_distribution_period_end_date  first_distribution_payment_date  \
# 0                                  NaT                              NaT
# 1                                  NaT                              NaT
# 2                                  NaT                              NaT
# 3                                  NaT                              NaT
# 4                                  NaT                              NaT
# 5                                  NaT                              NaT
# 6                                  NaT                              NaT
# 7                                  NaT                              NaT
# 8                                  NaT                              NaT
# 9                                  NaT                              NaT
# 10                                 NaT                              NaT
# 11                                 NaT                              NaT
# 12                          2017-12-31                       2017-12-07
# 13                                 NaT                              NaT
# 14                                 NaT                              NaT
# 15                                 NaT                              NaT
# 16                                 NaT                              NaT
# 17                                 NaT                              NaT
# 18                          2016-01-31                       2016-01-07
# 19                                 NaT                              NaT
# 20                          2019-09-30                       2019-10-10
# 21                                 NaT                              NaT
# 22                                 NaT                              NaT
# 23                                 NaT                              NaT
# 24                                 NaT                              NaT
# 25                          2019-09-30                       2019-10-10
# 26                                 NaT                              NaT
# 27                                 NaT                              NaT
# 28                                 NaT                              NaT
# 29                                 NaT                              NaT
# ..                                 ...                              ...
# 294                         1900-01-02                       1900-01-02
# 295                                NaT                              NaT
# 296                         2016-12-31                       2017-01-26
# 297                         2016-09-30                       2016-10-20
# 298                         2016-06-30                       2016-06-30
# 299                         2017-02-28                       2017-12-31
# 300                         2016-06-30                       2016-07-20
# 301                         2016-04-30                       2016-04-01
# 302                                NaT                              NaT
# 303                         2016-03-31                       2016-03-31
# 304                                NaT                              NaT
# 305                                NaT                              NaT
# 306                                NaT                              NaT
# 307                         2015-12-31                       2015-12-31
# 308                         2018-03-31                       2018-03-31
# 309                         2016-03-31                       2016-04-20
# 310                         2015-02-28                       2015-05-01
# 311                         2015-12-31                       2016-01-26
# 312                         2016-03-31                       2016-03-31
# 313                         2015-12-31                       2016-02-09
# 314                         2015-12-31                       2016-02-04
# 315                         2015-01-31                       2015-10-23
# 316                         2015-12-31                       2016-02-02
# 317                                NaT                              NaT
# 318                         2015-06-30                       2015-07-15
# 319                         2014-06-30                       2014-09-30
# 320                         2015-03-31                       2015-05-15
# 321                         2015-06-30                       2015-07-29
# 322                         2016-01-31                       2016-12-12
# 323                         2015-03-31                       2015-01-08
#
#      last_distribution_period_end_date  last_distribution_payment_date  \
# 0                                  NaT                             NaT
# 1                                  NaT                             NaT
# 2                                  NaT                             NaT
# 3                                  NaT                             NaT
# 4                                  NaT                             NaT
# 5                                  NaT                             NaT
# 6                                  NaT                             NaT
# 7                                  NaT                             NaT
# 8                                  NaT                             NaT
# 9                                  NaT                             NaT
# 10                                 NaT                             NaT
# 11                                 NaT                             NaT
# 12                          2019-06-30                      2019-08-01
# 13                                 NaT                             NaT
# 14                                 NaT                             NaT
# 15                                 NaT                             NaT
# 16                                 NaT                             NaT
# 17                                 NaT                             NaT
# 18                          2019-09-30                      2019-10-16
# 19                                 NaT                             NaT
# 20                          2019-09-30                      2019-10-10
# 21                                 NaT                             NaT
# 22                                 NaT                             NaT
# 23                                 NaT                             NaT
# 24                                 NaT                             NaT
# 25                          2019-09-30                      2019-10-10
# 26                                 NaT                             NaT
# 27                                 NaT                             NaT
# 28                                 NaT                             NaT
# 29                                 NaT                             NaT
# ..                                 ...                             ...
# 294                         2018-06-30                      2018-06-15
# 295                                NaT                             NaT
# 296                         2017-03-31                      2017-05-04
# 297                         2019-05-24                      2019-05-24
# 298                         2019-06-30                      2019-06-30
# 299                         2019-09-30                      2019-09-30
# 300                         2019-05-01                      2019-06-25
# 301                         2019-08-31                      2019-08-01
# 302                                NaT                             NaT
# 303                         2019-09-29                      2019-09-30
# 304                                NaT                             NaT
# 305                                NaT                             NaT
# 306                                NaT                             NaT
# 307                         2018-03-31                      2018-03-31
# 308                         2019-09-30                      2019-09-30
# 309                         2018-04-19                      2018-04-19
# 310                         2019-03-31                      2019-03-31
# 311                         2018-12-20                      2019-01-31
# 312                         2017-06-30                      2017-06-30
# 313                         2016-12-31                      2017-02-15
# 314                         2019-06-30                      2019-07-25
# 315                         2018-10-24                      2018-10-24
# 316                         2019-06-30                      2019-07-31
# 317                                NaT                             NaT
# 318                         2018-12-31                      2019-01-15
# 319                         2018-08-15                      2018-08-15
# 320                         2018-09-19                      2018-09-19
# 321                         2017-12-31                      2017-12-12
# 322                         2016-01-31                      2016-12-12
# 323                         2019-03-31                      2019-04-01
#
#     last_tax_document_date realized_investor_equity_multiple  \
# 0                      NaT                               NaN
# 1                      NaT                               NaN
# 2                      NaT                               NaN
# 3                      NaT                               NaN
# 4                      NaT                               NaN
# 5                      NaT                               NaN
# 6                      NaT                               NaN
# 7                      NaT                               NaN
# 8                      NaT                               NaN
# 9                      NaT                               NaN
# 10                     NaT                               NaN
# 11                     NaT                               NaN
# 12              2019-05-17                              0.03
# 13                     NaT                               NaN
# 14                     NaT                               NaN
# 15                     NaT                               NaN
# 16                     NaT                               NaN
# 17                     NaT                               NaN
# 18              2019-05-28                              0.21
# 19                     NaT                               NaN
# 20                     NaT                              0.01
# 21                     NaT                               NaN
# 22                     NaT                               NaN
# 23                     NaT                               NaN
# 24                     NaT                               NaN
# 25                     NaT                              0.01
# 26                     NaT                               NaN
# 27                     NaT                               NaN
# 28                     NaT                               NaN
# 29                     NaT                               NaN
# ..                     ...                               ...
# 294             2018-03-10                              0.11
# 295             2018-05-25                               NaN
# 296             2019-03-14                              0.01
# 297             2019-03-14                              2.31
# 298             2019-03-28                              1.57
# 299             2019-09-10                              0.02
# 300             2018-04-02                              1.69
# 301             2019-09-09                              0.54
# 302                    NaT                               NaN
# 303             2019-03-07                              0.72
# 304             2018-05-24                               NaN
# 305                    NaT                               NaN
# 306             2019-04-10                               NaN
# 307             2019-03-15                              0.24
# 308             2019-09-06                              0.05
# 309             2019-07-27                              0.18
# 310             2019-10-03                              0.32
# 311             2019-10-14                              1.52
# 312             2019-03-06                              0.38
# 313             2018-03-20                              0.11
# 314             2019-10-14                              0.29
# 315             2019-03-05                              0.84
# 316             2018-04-03                              0.58
# 317             2018-03-21                               NaN
# 318             2019-03-08                              0.28
# 319                    NaT                              1.12
# 320             2019-03-26                              1.63
# 321             2018-04-03                              1.42
# 322             2019-04-03                              0.25
# 323             2019-03-29                              0.39
#
#     realized_avg_annual_cash_yield_pct
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
# ..                                 ...
# 294                             0.0032
# 295                                NaN
# 296                             0.0004
# 297                             0.0692
# 298                             0.0470
# 299                             0.0006
# 300                             0.0508
# 301                             0.0163
# 302                                NaN
# 303                             0.0215
# 304                                NaN
# 305                                NaN
# 306                                NaN
# 307                             0.0071
# 308                             0.0015
# 309                             0.0054
# 310                             0.0096
# 311                             0.0455
# 312                             0.0113
# 313                             0.0045
# 314                             0.0116
# 315                             0.0336
# 316                             0.0234
# 317                                NaN
# 318                             0.0112
# 319                             0.0447
# 320                             0.0651
# 321                             0.0569
# 322                             0.0101
# 323                             0.0157
#
# [324 rows x 30 columns]
